# %%
import pandas as pd
import numpy as np
df = pd.read_excel("D:\Excelr_assignments\Association Rules\Association Rules\Online retail.xlsx")
df
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\dell\AppData\Local\Temp\ipykernel_19428\2063376253.py:3: SyntaxWarning: invalid escape sequence '\E'
#   df = pd.read_excel("D:\Excelr_assignments\Association Rules\Association Rules\Online retail.xlsx")
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# ...

# %%
# checking for the null values in the dataset :

df.isnull().sum()
# Out:
# shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil    0
# dtype: int64

# %%
# checking the shape of the dataset.

df.shape
# Out:
# (7500, 1)

# %%
# removing the null values in the data set :

df.dropna(inplace=True)

# %%
# checking the duplicates in the data set:

df.duplicated().sum()

# and we got 2325 duplicates in the dataset:
# Out:
# np.int64(2325)

# %%
# removing the duplicates from the data set:

df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7492  burgers,salmon,pancakes,french fries,frozen sm...
# 7493  turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [5175 rows x 1 columns]

# %%
# renaming the column name of the dataset which is so long:

df.rename(columns = {"shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil":"items"},inplace=True)
df["items"]
# Out:
# 0                                  burgers,meatballs,eggs
# 1                                                 chutney
# 2                                          turkey,avocado
# 3       mineral water,milk,energy bar,whole wheat rice...
# 4                                          low fat yogurt
#                               ...
# 7492    burgers,salmon,pancakes,french fries,frozen sm...
# 7493    turkey,burgers,dessert wine,shrimp,pasta,tomat...
# 7495                        butter,light mayo,fresh bread
# 7496    burgers,frozen vegetables,eggs,french fries,ma...
# 7499      eggs,frozen smoothie,yogurt cake,low fat yogurt
# Name: items, Length: 5175, dtype: object

# %%
# to remove the white spaces in the dataset:

df.columns = df.columns.str.strip()

# %%
# spliting the items into the list:

trans = df["items"].apply(lambda x: x.split(',')).tolist()
trans
# Out:
# [['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate'],
#  ['meatballs', 'milk', 'honey', 'french fries', 'protein bar'],
#  ['red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo'],
# ...

# %%
df.columns
# Out:
# Index(['items'], dtype='object')

# %%
len(trans)
# Out:
# 5175

# %%
rules = apriori(trans, 
                min_support=0.02,     
                min_confidence=0.3,    
                min_lift=1.2)         

# Convert to list
results = list(rules)
print("Number of rules generated:", len(results))
# Out:
# Number of rules generated: 30

# %%
for rule in results:
    items = list(rule.items)
    print(f"Rule: {items}")
    print(f"Support: {rule.support:.2f}")
    
    for stat in rule.ordered_statistics:
        print(f"  If {list(stat.items_base)} => Then {list(stat.items_add)}")
        print(f"    - Confidence: {stat.confidence:.2f}")
        print(f"    - Lift: {stat.lift:.2f}")
    print("-" * 50)
# Out:
# Rule: ['eggs', 'burgers']
# Support: 0.04
#   If ['burgers'] => Then ['eggs']
#     - Confidence: 0.32
#     - Lift: 1.53
# --------------------------------------------------
# Rule: ['mineral water', 'cake']
# Support: 0.04
#   If ['cake'] => Then ['mineral water']
#     - Confidence: 0.36
#     - Lift: 1.21
# --------------------------------------------------
# Rule: ['chicken', 'mineral water']
# Support: 0.03
#   If ['chicken'] => Then ['mineral water']
#     - Confidence: 0.39
#     - Lift: 1.30
# --------------------------------------------------
# Rule: ['cooking oil', 'mineral water']
# Support: 0.03
#   If ['cooking oil'] => Then ['mineral water']
#     - Confidence: 0.40
#     - Lift: 1.35
# --------------------------------------------------
# Rule: ['cooking oil', 'spaghetti']
# Support: 0.02
#   If ['cooking oil'] => Then ['spaghetti']
#     - Confidence: 0.32
#     - Lift: 1.38
# --------------------------------------------------
# Rule: ['eggs', 'turkey']
# ...

# %% [markdown]
# --> Frequent Pairs with High Confidence
#
# 1.cake → mineral water
# 2.ground beef → spaghetti
# 3.chocolate & milk → mineral water
#
#
# -->  Items That Frequently Appear in Rules
# 1.mineral water appears in many rules, e.g.:
#           spaghetti → mineral water
#           pancakes → mineral water
#           soup → mineral water

# %% [markdown]
#  Interview Questions:
#
# 1.lift :
#      lift is a measure which measures the two items that are bought together that the items bought individually.
#      lift = 0 ( it indicates that no association and they are independent)
#      lift > 1 ( positive assosiation and dependent)
#      lift < 1 ( negatively dependent)
#
# 2.support : it is nothing but it measures fraction of total transactions that contain the itemset.
#   confidence :it is nothing but the Probability that item B is bought given item A is bought.
#
# 3.->Too many rules
#   ->Meaningless patterns.
#   ->Rare item problem
#   ->Interpretability
#   ->No causation
